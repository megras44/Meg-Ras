# %%
#Change the following loop to go over a different interval other than 1 through 5:
for k in [1..5]:
    print(k)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#You can also make other lists for loops.
#Make your own list
for k in [pi, 2*pi]:
    print (k^2)
# Out:
# pi^2
# 4*pi^2

# %%
#You cannot write coefficients like this "2x".   Need to write 2*x instead.  
#The scripting code needs to be able to dsitinguish what is multiplication and what is not.
#Change the following code with a different polynomial where you need to use * instead.
f(x)=2*x^2+5
print(derivative(f(x)))
# Out:
# 4*x

# %%
#You can also graph a function.  If you use a variable other than "x" like "y", write var('y') first:
var('y')
implicit_plot(y==sin(x),(x,0,2*pi),(y,-2,2))
#Plot a different function of your choosing
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#You can also define a process:
def process(x):
    for k in [1..8]:
        x=x+k
    return x
#Now run the process:
process(5)
#Change the above process to do something else.
# Out:
# 41
